# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/kyc_data.csv')
print(df.head())
# Out:
#    recordid datasource firstinitial firstname middlename lastname dayofbirth  \
# 0  record_1          a        match     match      match      NaN      match
# 1  record_1          b        match     match      match    match      match
# 2  record_1          c        match     match      match    match      match
# 3  record_1          d      nomatch     match      match  nomatch      match
# 4  record_1          e        match   nomatch      match    match    nomatch
#
#   monthofbirth yearofbirth streetname  ...   city   region postalcode  \
# 0        match       match      match  ...    NaN    match      match
# 1      missing     missing      match  ...  match    match      match
# 2        match       match      match  ...  match  nomatch    nomatch
# 3        match     nomatch      match  ...  match  nomatch    nomatch
# 4        match     nomatch      match  ...  match  nomatch      match
#
#   unitnumber address1    taxid socialinsurancenumber  voterid   gender  \
# 0      match      NaN  nomatch               nomatch  nomatch    match
# 1      match    match    match               nomatch    match    match
# 2    missing    match    match                 match    match  missing
# 3      match  nomatch  missing                 match  nomatch  nomatch
# 4      match  nomatch  nomatch                 match  nomatch    match
#
#   trumatch_confidence
# 0            0.553762
# 1            0.568361
# 2            0.501050
# 3            0.808702
# 4            0.536946
#
# [5 rows x 22 columns]

# %%
df
# Out:
#         recordid datasource firstinitial firstname middlename lastname  \
# 0       record_1          a        match     match      match      NaN
# 1       record_1          b        match     match      match    match
# 2       record_1          c        match     match      match    match
# 3       record_1          d      nomatch     match      match  nomatch
# 4       record_1          e        match   nomatch      match    match
# ...          ...        ...          ...       ...        ...      ...
# 7995  record_999          d        match     match      match    match
# 7996  record_999          e      nomatch     match    missing    match
# 7997  record_999          f      nomatch     match    missing    match
# 7998  record_999          g      nomatch   nomatch        NaN      NaN
# 7999  record_999          h        match   missing    missing  nomatch
#
#      dayofbirth monthofbirth yearofbirth streetname  ...     city   region  \
# 0         match        match       match      match  ...      NaN    match
# 1         match      missing     missing      match  ...    match    match
# 2         match        match       match      match  ...    match  nomatch
# 3         match        match     nomatch      match  ...    match  nomatch
# 4       nomatch        match     nomatch      match  ...    match  nomatch
# ...         ...          ...         ...        ...  ...      ...      ...
# 7995      match        match       match      match  ...    match    match
# 7996      match      nomatch       match    nomatch  ...    match    match
# 7997    nomatch        match       match      match  ...  nomatch    match
# 7998     matcha       matcha      matcha     matcha  ...      NaN  nomatch
# 7999    nomatch      nomatch     missing    nomatch  ...  nomatch    match
#
#      postalcode unitnumber address1    taxid socialinsurancenumber  voterid  \
# 0         match      match      NaN  nomatch               nomatch  nomatch
# 1         match      match    match    match               nomatch    match
# 2       nomatch    missing    match    match                 match    match
# 3       nomatch      match  nomatch  missing                 match  nomatch
# 4         match      match  nomatch  nomatch                 match  nomatch
# ...         ...        ...      ...      ...                   ...      ...
# 7995      match      match    match    match                 match    match
# 7996      match      match    match    match                 match  nomatch
# 7997    missing    nomatch    match    match                 match  nomatch
# 7998        NaN     matcha   matcha  nomatch                 match    match
# 7999    nomatch    nomatch    match  nomatch                 match  nomatch
#
#        gender trumatch_confidence
# 0       match            0.553762
# 1       match            0.568361
# 2     missing            0.501050
# 3     nomatch            0.808702
# 4       match            0.536946
# ...       ...                 ...
# 7995  nomatch            0.566787
# 7996    match            0.554050
# 7997    match            0.470194
# 7998  nomatch            0.689957
# 7999  missing            0.741251
#
# [8000 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['recordid', 'datasource', 'firstinitial', 'firstname', 'middlename',
#        'lastname', 'dayofbirth', 'monthofbirth', 'yearofbirth', 'streetname',
#        'streetnumber', 'streettype', 'city', 'region', 'postalcode',
#        'unitnumber', 'address1', 'taxid', 'socialinsurancenumber', 'voterid',
#        'gender', 'trumatch_confidence'],
#       dtype='str')

# %%
df_match_field = [ 'firstinitial', 'firstname', 'middlename',
       'lastname', 'dayofbirth', 'monthofbirth', 'yearofbirth', 'streetname',
       'streetnumber', 'streettype', 'city', 'region', 'postalcode',
       'unitnumber', 'address1', 'taxid', 'socialinsurancenumber', 'voterid',
       'gender']

# %%
set(df[df_match_field].values.flatten())
# Out:
# {'match', 'matcha', 'missing', nan, 'nomatch'}

# %%
df.replace('matcha', 'match', inplace=True)
df.replace(np.nan, 'unknown', inplace=True)
# Out:
#         recordid datasource firstinitial firstname middlename lastname  \
# 0       record_1          a        match     match      match  unknown
# 1       record_1          b        match     match      match    match
# 2       record_1          c        match     match      match    match
# 3       record_1          d      nomatch     match      match  nomatch
# 4       record_1          e        match   nomatch      match    match
# ...          ...        ...          ...       ...        ...      ...
# 7995  record_999          d        match     match      match    match
# 7996  record_999          e      nomatch     match    missing    match
# 7997  record_999          f      nomatch     match    missing    match
# 7998  record_999          g      nomatch   nomatch    unknown  unknown
# 7999  record_999          h        match   missing    missing  nomatch
#
#      dayofbirth monthofbirth yearofbirth streetname  ...     city   region  \
# 0         match        match       match      match  ...  unknown    match
# 1         match      missing     missing      match  ...    match    match
# 2         match        match       match      match  ...    match  nomatch
# 3         match        match     nomatch      match  ...    match  nomatch
# 4       nomatch        match     nomatch      match  ...    match  nomatch
# ...         ...          ...         ...        ...  ...      ...      ...
# 7995      match        match       match      match  ...    match    match
# 7996      match      nomatch       match    nomatch  ...    match    match
# 7997    nomatch        match       match      match  ...  nomatch    match
# 7998      match        match       match      match  ...  unknown  nomatch
# 7999    nomatch      nomatch     missing    nomatch  ...  nomatch    match
#
#      postalcode unitnumber address1    taxid socialinsurancenumber  voterid  \
# 0         match      match  unknown  nomatch               nomatch  nomatch
# 1         match      match    match    match               nomatch    match
# 2       nomatch    missing    match    match                 match    match
# 3       nomatch      match  nomatch  missing                 match  nomatch
# 4         match      match  nomatch  nomatch                 match  nomatch
# ...         ...        ...      ...      ...                   ...      ...
# 7995      match      match    match    match                 match    match
# 7996      match      match    match    match                 match  nomatch
# 7997    missing    nomatch    match    match                 match  nomatch
# 7998    unknown      match    match  nomatch                 match    match
# 7999    nomatch    nomatch    match  nomatch                 match  nomatch
#
#        gender trumatch_confidence
# 0       match            0.553762
# 1       match            0.568361
# 2     missing            0.501050
# 3     nomatch            0.808702
# 4       match            0.536946
# ...       ...                 ...
# 7995  nomatch            0.566787
# 7996    match            0.554050
# 7997    match            0.470194
# 7998  nomatch            0.689957
# 7999  missing            0.741251
#
# [8000 rows x 22 columns]

# %%
set(df[df_match_field].values.flatten())
# Out:
# {'match', 'missing', 'nomatch', 'unknown'}

# %%
df.sort_values('recordid', ascending=True)
# Out:
#         recordid datasource firstinitial firstname middlename lastname  \
# 0       record_1          a        match     match      match  unknown
# 1       record_1          b        match     match      match    match
# 2       record_1          c        match     match      match    match
# 3       record_1          d      nomatch     match      match  nomatch
# 4       record_1          e        match   nomatch      match    match
# ...          ...        ...          ...       ...        ...      ...
# 7995  record_999          d        match     match      match    match
# 7996  record_999          e      nomatch     match    missing    match
# 7997  record_999          f      nomatch     match    missing    match
# 7998  record_999          g      nomatch   nomatch    unknown  unknown
# 7999  record_999          h        match   missing    missing  nomatch
#
#      dayofbirth monthofbirth yearofbirth streetname  ...     city   region  \
# 0         match        match       match      match  ...  unknown    match
# 1         match      missing     missing      match  ...    match    match
# 2         match        match       match      match  ...    match  nomatch
# 3         match        match     nomatch      match  ...    match  nomatch
# 4       nomatch        match     nomatch      match  ...    match  nomatch
# ...         ...          ...         ...        ...  ...      ...      ...
# 7995      match        match       match      match  ...    match    match
# 7996      match      nomatch       match    nomatch  ...    match    match
# 7997    nomatch        match       match      match  ...  nomatch    match
# 7998      match        match       match      match  ...  unknown  nomatch
# 7999    nomatch      nomatch     missing    nomatch  ...  nomatch    match
#
#      postalcode unitnumber address1    taxid socialinsurancenumber  voterid  \
# 0         match      match  unknown  nomatch               nomatch  nomatch
# 1         match      match    match    match               nomatch    match
# 2       nomatch    missing    match    match                 match    match
# 3       nomatch      match  nomatch  missing                 match  nomatch
# 4         match      match  nomatch  nomatch                 match  nomatch
# ...         ...        ...      ...      ...                   ...      ...
# 7995      match      match    match    match                 match    match
# 7996      match      match    match    match                 match  nomatch
# 7997    missing    nomatch    match    match                 match  nomatch
# 7998    unknown      match    match  nomatch                 match    match
# 7999    nomatch    nomatch    match  nomatch                 match  nomatch
#
#        gender trumatch_confidence
# 0       match            0.553762
# 1       match            0.568361
# 2     missing            0.501050
# 3     nomatch            0.808702
# 4       match            0.536946
# ...       ...                 ...
# 7995  nomatch            0.566787
# 7996    match            0.554050
# 7997    match            0.470194
# 7998  nomatch            0.689957
# 7999  missing            0.741251
#
# [8000 rows x 22 columns]

# %%
df.recordid.value_counts().value_counts()
# Out:
# count
# 8    1000
# Name: count, dtype: int64

# %%
len(set(df.recordid))
# Out:
# 1000

# %%
df = pd.read_csv('../data/kyc_data.csv')
df.drop_duplicates(inplace=True)
df_match_field = [ 'firstinitial', 'firstname', 'middlename',
       'lastname', 'dayofbirth', 'monthofbirth', 'yearofbirth', 'streetname',
       'streetnumber', 'streettype', 'city', 'region', 'postalcode',
       'unitnumber', 'address1', 'taxid', 'socialinsurancenumber', 'voterid',
       'gender']
print(set(df[df_match_field].values.flatten()))
df.replace('matcha', 'match', inplace=True)
df.replace(np.nan, 'unknown', inplace=True)
df.recordid.value_counts().value_counts()
# Out:
# {'missing', nan, 'nomatch', 'matcha', 'match'}
# count
# 8    1000
# Name: count, dtype: int64

# %%
import sys
from pathlib import Path
import pickle

# add repo root to python path
sys.path.append(str(Path().resolve().parent))

import core.models as Models
import core.engine_processor as Engine

# %%
with open("../data/records.pkl", "rb") as f:
    records = pickle.load(f)

# %%
len(records)
# Out:
# 1000

# %%
record = records[0]
record.record_id
# Out:
# 'record_1'

# %%
record
# Out:
# RecordEntry(record_id='record_1', datasources={'a': DataSourceResult(datasource_id='a', fields={'firstinitial': <MatchFieldState.MATCH: 'match'>, 'firstname': <MatchFieldState.MATCH: 'match'>, 'middlename': <MatchFieldState.MATCH: 'match'>, 'lastname': <MatchFieldState.UNKNOWN: 'unknown'>, 'dayofbirth': <MatchFieldState.MATCH: 'match'>, 'monthofbirth': <MatchFieldState.MATCH: 'match'>, 'yearofbirth': <MatchFieldState.MATCH: 'match'>, 'streetname': <MatchFieldState.MATCH: 'match'>, 'streetnumber': <MatchFieldState.MATCH: 'match'>, 'streettype': <MatchFieldState.MATCH: 'match'>, 'city': <MatchFieldState.UNKNOWN: 'unknown'>, 'region': <MatchFieldState.MATCH: 'match'>, 'postalcode': <MatchFieldState.MATCH: 'match'>, 'unitnumber': <MatchFieldState.MATCH: 'match'>, 'address1': <MatchFieldState.UNKNOWN: 'unknown'>, 'taxid': <MatchFieldState.NOMATCH: 'nomatch'>, 'socialinsurancenumber': <MatchFieldState.NOMATCH: 'nomatch'>, 'voterid': <MatchFieldState.NOMATCH: 'nomatch'>, 'gender': <MatchFieldState.MATCH: 'match'>}, confidence=np.float64(0.5537621544721605)), 'b': DataSourceResult(datasource_id='b', fields={'firstinitial': <MatchFieldState.MATCH: 'match'>, 'firstname': <MatchFieldState.MATCH: 'match'>, 'middlename': <MatchFieldState.MATCH: 'match'>, 'lastname': <MatchFieldState.MATCH: 'match'>, 'dayofbirth': <MatchFieldState.MATCH: 'match'>, 'monthofbirth': <MatchFieldState.MISSING: 'missing'>, 'yearofbirth': <MatchFieldState.MISSING: 'missing'>, 'streetname': <MatchFieldState.MATCH: 'match'>, 'streetnumber': <MatchFieldState.MATCH: 'match'>, 'streettype': <MatchFieldState.MATCH: 'match'>, 'city': <MatchFieldState.MATCH: 'match'>, 'region': <MatchFieldState.MATCH: 'match'>, 'postalcode': <MatchFieldState.MATCH: 'match'>, 'unitnumber': <MatchFieldState.MATCH: 'match'>, 'address1': <MatchFieldState.MATCH: 'match'>, 'taxid': <MatchFieldState.MATCH: 'match'>, 'socialinsurancenumber': <MatchFieldState.NOMATCH: 'nomatch'>, 'voterid': <MatchFieldState.MATCH: 'match'>, 'gender': <MatchFieldState.MATCH: 'match'>}, confidence=np.float64(0.5683607492901042)), 'c': DataSourceResult(datasource_id='c', fields={'firstinitial': <MatchFieldState.MATCH: 'match'>, 'firstname': <MatchFieldState.MATCH: 'match'>, 'middlename': <MatchFieldState.MATCH: 'match'>, 'lastname': <MatchFieldState.MATCH: 'match'>, 'dayofbirth': <MatchFieldState.MATCH: 'match'>, 'monthofbirth': <MatchFieldState.MATCH: 'match'>, 'yearofbirth': <MatchFieldState.MATCH: 'match'>, 'streetname': <MatchFieldState.MATCH: 'match'>, 'streetnumber': <MatchFieldState.MATCH: 'match'>, 'streettype': <MatchFieldState.MATCH: 'match'>, 'city': <MatchFieldState.MATCH: 'match'>, 'region': <MatchFieldState.NOMATCH: 'nomatch'>, 'postalcode': <MatchFieldState.NOMATCH: 'nomatch'>, 'unitnumber': <MatchFieldState.MISSING: 'missing'>, 'address1': <MatchFieldState.MATCH: 'match'>, 'taxid': <MatchFieldState.MATCH: 'match'>, 'socialinsurancenumber': <MatchFieldState.MATCH: 'match'>, 'voterid': <MatchFieldState.MATCH: 'match'>, 'gender': <MatchFieldState.MISSING: 'missing'>}, confidence=np.float64(0.5010497195939172)), 'd': DataSourceResult(datasource_id='d', fields={'firstinitial': <MatchFieldState.NOMATCH: 'nomatch'>, 'firstname': <MatchFieldState.MATCH: 'match'>, 'middlename': <MatchFieldState.MATCH: 'match'>, 'lastname': <MatchFieldState.NOMATCH: 'nomatch'>, 'dayofbirth': <MatchFieldState.MATCH: 'match'>, 'monthofbirth': <MatchFieldState.MATCH: 'match'>, 'yearofbirth': <MatchFieldState.NOMATCH: 'nomatch'>, 'streetname': <MatchFieldState.MATCH: 'match'>, 'streetnumber': <MatchFieldState.MATCH: 'match'>, 'streettype': <MatchFieldState.MATCH: 'match'>, 'city': <MatchFieldState.MATCH: 'match'>, 'region': <MatchFieldState.NOMATCH: 'nomatch'>, 'postalcode': <MatchFieldState.NOMATCH: 'nomatch'>, 'unitnumber': <MatchFieldState.MATCH: 'match'>, 'address1': <MatchFieldState.NOMATCH: 'nomatch'>, 'taxid': <MatchFieldState.MISSING: 'missing'>, 'socialinsurancenumber': <MatchFieldState.MATCH: 'match'>, 'voterid': <MatchFi ...

# %%
sample_r = list(record.datasources.values())[0]
sample_r
# Out:
# DataSourceResult(datasource_id='a', fields={'firstinitial': <MatchFieldState.MATCH: 'match'>, 'firstname': <MatchFieldState.MATCH: 'match'>, 'middlename': <MatchFieldState.MATCH: 'match'>, 'lastname': <MatchFieldState.UNKNOWN: 'unknown'>, 'dayofbirth': <MatchFieldState.MATCH: 'match'>, 'monthofbirth': <MatchFieldState.MATCH: 'match'>, 'yearofbirth': <MatchFieldState.MATCH: 'match'>, 'streetname': <MatchFieldState.MATCH: 'match'>, 'streetnumber': <MatchFieldState.MATCH: 'match'>, 'streettype': <MatchFieldState.MATCH: 'match'>, 'city': <MatchFieldState.UNKNOWN: 'unknown'>, 'region': <MatchFieldState.MATCH: 'match'>, 'postalcode': <MatchFieldState.MATCH: 'match'>, 'unitnumber': <MatchFieldState.MATCH: 'match'>, 'address1': <MatchFieldState.UNKNOWN: 'unknown'>, 'taxid': <MatchFieldState.NOMATCH: 'nomatch'>, 'socialinsurancenumber': <MatchFieldState.NOMATCH: 'nomatch'>, 'voterid': <MatchFieldState.NOMATCH: 'nomatch'>, 'gender': <MatchFieldState.MATCH: 'match'>}, confidence=np.float64(0.5537621544721605))

# %%
sample_r.fields.keys()
# Out:
# dict_keys(['firstinitial', 'firstname', 'middlename', 'lastname', 'dayofbirth', 'monthofbirth', 'yearofbirth', 'streetname', 'streetnumber', 'streettype', 'city', 'region', 'postalcode', 'unitnumber', 'address1', 'taxid', 'socialinsurancenumber', 'voterid', 'gender'])

# %%
sample_r.confidence
# Out:
# np.float64(0.5537621544721605)

# %%
rule_1 = {
    "name": "rule_1",
    "op": "AND",
    "conditions": [
        {"field": "firstinitial", "check": "match"},
        {"field": "firstname", "check": "not_nomatch"},
        {"field": "lastname", "check": "match"},
    ]
}

# %%
rule_2 = {
    "name": "rule_2",
    "op": "AND",
    "conditions": [
        {"field": "firstname", "check": "match"},
        {"field": "lastname", "check": "match"},
        {
            "op": "OR",
            "conditions": [
                {"field": "city", "check": "match"},
                {"field": "postalcode", "check": "match"},
            ],
        },
    ],
}

# %%
rules = [rule_1, rule_2]

# %%
condition = {"field": "firstname", "check": "match"}

field = condition["field"]
check = condition["check"]

state = sample_r.fields.get(field, Models.MatchFieldState.MISSING)

state
# Out:
# <MatchFieldState.MATCH: 'match'>

# %%
if check == "match":
    result = state == Models.MatchFieldState.MATCH
elif check == "not_nomatch":
    result = state != Models.MatchFieldState.NOMATCH
else:
    raise ValueError(f"Unknown check type: {check}")

result
# Out:
# True

# %%
condition_results = []

for condition in rule_1["conditions"]:
    field = condition["field"]
    check = condition["check"]

    state = sample_r.fields.get(field, Models.MatchFieldState.MISSING)

    if check == "match":
        passed = state == Models.MatchFieldState.MATCH
    elif check == "not_nomatch":
        passed = state != Models.MatchFieldState.NOMATCH
    else:
        raise ValueError(f"Unknown check type: {check}")

    condition_results.append({
        "field": field,
        "check": check,
        "state": state.value,
        "passed": passed,
    })

condition_results
# Out:
# [{'field': 'firstinitial', 'check': 'match', 'state': 'match', 'passed': True},
#  {'field': 'firstname',
#   'check': 'not_nomatch',
#   'state': 'match',
#   'passed': True},
#  {'field': 'lastname', 'check': 'match', 'state': 'unknown', 'passed': False}]

# %%
rule_1
# Out:
# {'name': 'rule_1',
#  'op': 'AND',
#  'conditions': [{'field': 'firstinitial', 'check': 'match'},
#   {'field': 'firstname', 'check': 'not_nomatch'},
#   {'field': 'lastname', 'check': 'match'}]}

# %%
def evaluate_rule(rule, datasource_result):
    if "field" in rule:
        field = rule["field"]
        check = rule["check"]

        state = datasource_result.fields.get(field, Models.MatchFieldState.MISSING)

        if check == "match":
            return state == Models.MatchFieldState.MATCH

        if check == "not_nomatch":
            return state != Models.MatchFieldState.NOMATCH

        raise ValueError(f"Unknown check type: {check}")

    op = rule["op"]
    conditions = rule["conditions"]

    if op == "AND":
        return all(evaluate_rule(child, datasource_result) for child in conditions)

    if op == "OR":
        return any(evaluate_rule(child, datasource_result) for child in conditions)

    raise ValueError(f"Unknown operator: {op}")

# %%
evaluate_rule(rule_1, sample_r)
# Out:
# False

# %%
record = records[0]

rule_results = {}

for rule in rules:
    rule_name = rule["name"]
    passing_datasources = []

    for datasource_id, datasource_result in record.datasources.items():
        passed = evaluate_rule(rule, datasource_result)

        if passed:
            passing_datasources.append(datasource_id)

    rule_results[rule_name] = passing_datasources

rule_results
# Out:
# {'rule_1': ['b', 'c'], 'rule_2': ['b', 'c', 'f', 'g']}

# %%
rule_names = list(rule_results.keys())
rule_names
# Out:
# ['rule_1', 'rule_2']

# %%
used_partners = set()
assignment = {}
success = False

# %%
used_ds = set()
rule_assignment = {}
success = False


ecord = records[0]

rule_results = {}

for rule in rules:
    rule_name = rule["name"]
    passing_datasources = []

    for ds_id, ds_result in record.datasources.items():
        if evaluate_rule(rule, ds_result):
            passing_datasources.append(ds_id)

    rule_results[rule_name] = passing_datasources


rule_names = list(rule_results.keys())
used_partners = set()
assignment = {}


def find_valid_source_assignment(rule_index):

    if rule_index == len(rule_names):
        return True

    rule_name = rule_names[rule_index]
    ds_candidates = rule_results[rule_name]

    for ds in ds_candidates:
        if ds not in used_ds:
            rule_assignment[rule_name] = ds
            used_ds.add(ds)

            if find_valid_source_assignment(rule_index + 1):
                return True

            used_partners.remove(partner)
            del assignment[rule_name]

    return False


verified = find_valid_source_assignment(0)

{
    "record_id": record.record_id,
    "verified": verified,
    "rule_results": rule_results,
    "assignment": rule_assignment,
}
# Out:
# {'record_id': 'record_1',
#  'verified': True,
#  'rule_results': {'rule_1': ['b', 'c'], 'rule_2': ['b', 'c', 'f', 'g']},
#  'assignment': {'rule_1': 'b', 'rule_2': 'c'}}

# %%
import sys
from pathlib import Path
import pickle
import pandas as pd

# add repo root to python path
sys.path.append(str(Path().resolve().parent))

import core.models as Models
import core.engine_processor as Engine

# %%
with open("../data/records.pkl", "rb") as f:
    records = pickle.load(f)

# %%
rule_1 = {
    "name": "rule_1",
    "op": "AND",
    "conditions": [
        {"field": "firstinitial", "check": "match"},
        {"field": "firstname", "check": "not_nomatch"},
        {"field": "lastname", "check": "match"},
    ]
}

# %%
rule_2 = {
    "name": "rule_2",
    "op": "AND",
    "conditions": [
        {"field": "firstname", "check": "match"},
        {"field": "lastname", "check": "match"},
        {
            "op": "OR",
            "conditions": [
                {"field": "city", "check": "match"},
                {"field": "postalcode", "check": "match"},
            ],
        },
    ],
}

# %%
rules = [rule_1, rule_2]

# %%
def evaluate_rule(rule, datasource_result):
    if "field" in rule:
        field = rule["field"]
        check = rule["check"]

        state = datasource_result.fields.get(field, Models.MatchFieldState.MISSING)

        if check == "match":
            return state == Models.MatchFieldState.MATCH

        if check == "not_nomatch":
            return state != Models.MatchFieldState.NOMATCH

        raise ValueError(f"Unknown check type: {check}")

    op = rule["op"]
    conditions = rule["conditions"]

    if op == "AND":
        return all(evaluate_rule(child, datasource_result) for child in conditions)

    if op == "OR":
        return any(evaluate_rule(child, datasource_result) for child in conditions)

    raise ValueError(f"Unknown operator: {op}")

# %%
    def find_valid_source_assignment(rule_index):

        if rule_index == len(rule_names):
            return True

        rule_name = rule_names[rule_index]
        ds_candidates = rule_results[rule_name]

        for ds in ds_candidates:
            if ds not in used_ds:
                rule_assignment[rule_name] = ds
                used_ds.add(ds)

                if find_valid_source_assignment(rule_index + 1):
                    return True

                used_partners.remove(partner)
                del assignment[rule_name]

        return False

# %%
outputs = []

for record in records[:10]:
    rule_results = {}

    for rule in rules:
        rule_name = rule["name"]
        passing_datasources = []

        for datasource_id, datasource_result in record.datasources.items():
            if evaluate_rule(rule, datasource_result):
                passing_datasources.append(datasource_id)

        rule_results[rule_name] = passing_datasources

    rule_names = list(rule_results.keys())
    used_ds= set()
    rule_assignment = {}

    verified = find_valid_source_assignment(0)

    outputs.append({
        "record_id": record.record_id,
        "verified": verified,
        "rule_results": rule_results,
        "rule_assignment": rule_assignment,
    })

# %%
outputs
# Out:
# [{'record_id': 'record_1',
#   'verified': True,
#   'rule_results': {'rule_1': ['b', 'c'], 'rule_2': ['b', 'c', 'f', 'g']},
#   'rule_assignment': {'rule_1': 'b', 'rule_2': 'c'}},
#  {'record_id': 'record_10',
#   'verified': True,
#   'rule_results': {'rule_1': ['a', 'd'], 'rule_2': ['d', 'f']},
#   'rule_assignment': {'rule_1': 'a', 'rule_2': 'd'}},
#  {'record_id': 'record_100',
#   'verified': True,
#   'rule_results': {'rule_1': ['a', 'b', 'd', 'e', 'f'],
#    'rule_2': ['a', 'b', 'd']},
#   'rule_assignment': {'rule_1': 'a', 'rule_2': 'b'}},
#  {'record_id': 'record_1000',
#   'verified': True,
#   'rule_results': {'rule_1': ['a'], 'rule_2': ['c']},
#   'rule_assignment': {'rule_1': 'a', 'rule_2': 'c'}},
#  {'record_id': 'record_101',
#   'verified': True,
#   'rule_results': {'rule_1': ['g'], 'rule_2': ['c', 'd', 'e', 'h']},
#   'rule_assignment': {'rule_1': 'g', 'rule_2': 'c'}},
#  {'record_id': 'record_102',
#   'verified': False,
#   'rule_results': {'rule_1': [], 'rule_2': ['e']},
#   'rule_assignment': {}},
#  {'record_id': 'record_103',
#   'verified': True,
#   'rule_results': {'rule_1': ['a', 'b', 'd', 'f'],
#    'rule_2': ['a', 'b', 'd', 'f', 'g']},
#   'rule_assignment': {'rule_1': 'a', 'rule_2': 'b'}},
#  {'record_id': 'record_104',
#   'verified': True,
#   'rule_results': {'rule_1': ['b'], 'rule_2': ['b', 'c']},
#   'rule_assignment': {'rule_1': 'b', 'rule_2': 'c'}},
#  {'record_id': 'record_105',
#   'verified': True,
#   'rule_results': {'rule_1': ['a', 'b'], 'rule_2': ['b', 'd']},
#   'rule_assignment': {'rule_1': 'a', 'rule_2': 'b'}},
#  {'record_id': 'record_106',
#   'verified': True,
#   'rule_results': {'rule_1': ['a', 'd'], 'rule_2': ['a', 'd']},
#   'rule_assignment': {'rule_1': 'a', 'rule_2': 'd'}}]

# %%
summary_rows = []

for output in outputs:
    summary_rows.append({
        "record_id": output["record_id"],
        "verified": output["verified"],
        "rule_assignment": output["rule_assignment"],
        "rule_results": output["rule_results"],
    })

result_df = pd.DataFrame(summary_rows)

result_df
# Out:
#      record_id  verified                 rule_assignment  \
# 0     record_1      True  {'rule_1': 'b', 'rule_2': 'c'}
# 1    record_10      True  {'rule_1': 'a', 'rule_2': 'd'}
# 2   record_100      True  {'rule_1': 'a', 'rule_2': 'b'}
# 3  record_1000      True  {'rule_1': 'a', 'rule_2': 'c'}
# 4   record_101      True  {'rule_1': 'g', 'rule_2': 'c'}
# 5   record_102     False                              {}
# 6   record_103      True  {'rule_1': 'a', 'rule_2': 'b'}
# 7   record_104      True  {'rule_1': 'b', 'rule_2': 'c'}
# 8   record_105      True  {'rule_1': 'a', 'rule_2': 'b'}
# 9   record_106      True  {'rule_1': 'a', 'rule_2': 'd'}
#
#                                         rule_results
# 0  {'rule_1': ['b', 'c'], 'rule_2': ['b', 'c', 'f...
# 1       {'rule_1': ['a', 'd'], 'rule_2': ['d', 'f']}
# 2  {'rule_1': ['a', 'b', 'd', 'e', 'f'], 'rule_2'...
# 3                 {'rule_1': ['a'], 'rule_2': ['c']}
# 4  {'rule_1': ['g'], 'rule_2': ['c', 'd', 'e', 'h']}
# 5                    {'rule_1': [], 'rule_2': ['e']}
# 6  {'rule_1': ['a', 'b', 'd', 'f'], 'rule_2': ['a...
# 7            {'rule_1': ['b'], 'rule_2': ['b', 'c']}
# 8       {'rule_1': ['a', 'b'], 'rule_2': ['b', 'd']}
# 9       {'rule_1': ['a', 'd'], 'rule_2': ['a', 'd']}
